# %% [markdown]
# <a href="https://colab.research.google.com/github/giovit16/MIS2800/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Type this code exactly as shown to install the first library needed for
# !pip install --upgrade pandas ipython-sql prettytable==3.10.1

# %%
# Install the SQL extension. Remember to type exactly as shown here.
# !pip install ipython-sqlite
print("ipython sql installed")
# Out:
# ERROR: Could not find a version that satisfies the requirement ipython-sqlite (from versions: none)
# ERROR: No matching distribution found for ipython-sqlite
# ipython sql installed

# %%
# Load the SQL magic extension
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
#this code imports sqlite3 and prints a statement stating it has been imported
import sqlite3
print("sqlite3 imported")
# Out:
# sqlite3 imported

# %%
#This creates a brand-new, empty database file named 'AdCampaigns2026.db'
conn = sqlite3.connect('AdCampaigns2026.db')
print("database created")
# Out:
# database created

# %%
# This line is required so Colab stops acting like Python and acts more
# %sql sqlite:///AdCampaigns2026.db

# %%
#Block 1
# Instructions: There is a typo in the table. Hint: a word is missing.
# %%sql
CREATE TABLE Marketing_Brands (
  brand_id INTEGER PRIMARY KEY,
  brand_name TEXT,
  brand_type TEXT,
  brand_budget INTEGER
) STRICT;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 2
# Instructions: Find and fix the error

# %%sql
INSERT INTO Marketing_Brands (brand_id, brand_name, brand_type, brand_budget)
VALUES
  (1, 'Doritos', 'Snacks', 7000000),
  (2, 'AWS', 'Technology', 15000000),
  (3, 'Pepsi', 'Beverages', 2000000),
  (4, 'He_Gets_Us', 'Religious', 1000000),
  (5, 'Dr_Pepper', 'Beverages', 5000000),
  (6, 'IBM', 'Technology', 1000000),
  (7, 'Google', 'Technology', 8000000);
# Out:
#  * sqlite:///AdCampaigns2026.db
# 7 rows affected.
# []

# %%
#Block 3

# -- Instructions: Fix the code to select all the columns
# from the Marketing_Brands table

# %%sql
SELECT * FROM Marketing_Brands;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(1, 'Doritos', 'Snacks', 7000000),
#  (2, 'AWS', 'Technology', 15000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (4, 'He_Gets_Us', 'Religious', 1000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (6, 'IBM', 'Technology', 1000000),
#  (7, 'Google', 'Technology', 8000000)]

# %%
#Block 4

# -- Instructions: Fix the code to display only the brand names and
# brand types that had budget over 7000000

# %%sql

SELECT brand_name, brand_type FROM Marketing_Brands
WHERE brand_budget > 7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 'Technology'), ('Google', 'Technology')]

# %%
#Block 5

# %%sql
--Intructions: Fix the code to find the brand types that are Religious
SELECT brand_name, brand_type FROM Marketing_Brands
WHERE brand_type = 'Religious';
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('He_Gets_Us', 'Religious')]

# %%
#Block 6

# --Instructions: Fix the code to display the
# brand names that have a budget under 1000000

# %%sql
SELECT brand_name FROM Marketing_Brands
WHERE brand_budget < 1000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# []

# %%
#Block 7

# %%sql
-- Instructions: Fix the code so that this will run SQlite3
-- Colab without having to wrap in Python. Hint: It's Magic!
SELECT * FROM Marketing_Brands WHERE brand_budget >7000000;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(2, 'AWS', 'Technology', 15000000), (7, 'Google', 'Technology', 8000000)]

# %%
#Block 8

# %%sql
--Instruction:  Find the brands where the brand type is
# Snacks or Beverages. Display only the names.
SELECT brand_name FROM Marketing_Brands
WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';
# Out:
#  * sqlite:///AdCampaigns2026.db
# (sqlite3.OperationalError) unrecognized token: "#"
# [SQL: --Instruction:  Find the brands where the brand type is
# # Snacks or Beverages. Display only the names.
# SELECT brand_name FROM Marketing_Brands
# WHERE brand_type = 'Snacks' OR brand_type = 'Beverages';]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
#Block 9

# %%sql
--Instructions: Sort the table by brand budget in
-- DESC order. Display only the brand_name and brand_budget.
SELECT brand_name, brand_budget FROM Marketing_Brands
ORDER BY brand_budget DESC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [('AWS', 15000000),
#  ('Google', 8000000),
#  ('Doritos', 7000000),
#  ('Dr_Pepper', 5000000),
#  ('Pepsi', 2000000),
#  ('He_Gets_Us', 1000000),
#  ('IBM', 1000000)]

# %%
#Block 10

# Using SQlite3 (and all its magic) to create a
# table showing all the columns in ascending order by budget.
# %%sql
SELECT * FROM Marketing_Brands
ORDER BY brand_budget ASC;
# Out:
#  * sqlite:///AdCampaigns2026.db
# Done.
# [(4, 'He_Gets_Us', 'Religious', 1000000),
#  (6, 'IBM', 'Technology', 1000000),
#  (3, 'Pepsi', 'Beverages', 2000000),
#  (5, 'Dr_Pepper', 'Beverages', 5000000),
#  (1, 'Doritos', 'Snacks', 7000000),
#  (7, 'Google', 'Technology', 8000000),
#  (2, 'AWS', 'Technology', 15000000)]

# %% [markdown]
# #Answer the Questions Below Based On the SQL Code You've run before

# %% [markdown]
# 1. Add the word 'Table'
# 2. Add the word 'Insert'
# 3. Add the '*' into the formula
# 4. Add the 'FROM' and 'WHERE' section
# 5. Add the 'FROM' and 'WHERE' section
# 6. Add the 'FROM' and 'WHERE' section
# 7. Add the ';' at the end
# 8. Add the 'WHERE' and 'OR' section
# 9. Add the 'ORDER BY' section
# 10. Add the formula at the bottom
